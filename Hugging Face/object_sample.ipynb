# %%
# !pip install transformers
# !pip install gradio
# !pip install timm
# !pip install inflect
# !pip install phonemizer
# Out:
# Requirement already satisfied: transformers in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (4.40.1)
# Requirement already satisfied: filelock in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.8.0)
# Requirement already satisfied: colorama in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: gradio in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (4.29.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (5.2.0)
# Requirement already satisfied: fastapi in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (0.111.0)
# Requirement already satisfied: ffmpy in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (0.3.2)
# Requirement already satisfied: gradio-client==0.16.1 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (0.16.1)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (0.22.2)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (2.1.1)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (3.7.2)
# Requirement already satisfied: numpy~=1.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (1.24.3)
# Requirement already satisfied: orjson~=3.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (3.10.0)
# Requirement already satisfied: packaging in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (2.0.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (9.4.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (2.3.0)
# Requirement already satisfied: pydub in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (0.4.3)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (0.12.3)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (4.8.0)
# Requirement already satisfied: urllib3~=2.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (2.2.1)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio) (0.29.0)
# Requirement already satisfied: fsspec in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio-client==0.16.1->gradio) (2024.2.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from gradio-client==0.16.1->gradio) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (4.17.3)
# Requirement already satisfied: toolz in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.1)
# Requirement already satisfied: anyio in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from httpx>=0.24.1->gradio) (3.5.0)
# Requirement already satisfied: certifi in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from httpx>=0.24.1->gradio) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: idna in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from httpx>=0.24.1->gradio) (3.4)
# Requirement already satisfied: sniffio in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from httpx>=0.24.1->gradio) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (3.13.1)
# Requirement already satisfied: requests in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from matplotlib~=3.0->gradio) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from matplotlib~=3.0->gradio) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from matplotlib~=3.0->gradio) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from pydantic>=2.0->gradio) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from pydantic>=2.0->gradio) (2.6.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from fastapi->gradio) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from fastapi->gradio) (0.0.2)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from fastapi->gradio) (5.9.0)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from fastapi->gradio) (2.1.1)
# Requirement already satisfied: colorama in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.4)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from email_validator>=2.0.0->fastapi->gradio) (2.4.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.18.0)
# Requirement already satisfied: six>=1.5 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.16.1)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio) (1.0.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio) (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio) (3.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Collecting timm
#   Downloading timm-0.9.16-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: torch in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from timm) (2.3.0+cu118)
# Requirement already satisfied: torchvision in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from timm) (0.18.0+cu118)
# Requirement already satisfied: pyyaml in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface_hub in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from timm) (0.22.2)
# Requirement already satisfied: safetensors in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from timm) (0.4.3)
# Requirement already satisfied: filelock in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from huggingface_hub->timm) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from huggingface_hub->timm) (2024.2.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from huggingface_hub->timm) (23.2)
# Requirement already satisfied: requests in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from huggingface_hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from huggingface_hub->timm) (4.66.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from huggingface_hub->timm) (4.8.0)
# Requirement already satisfied: sympy in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from torch->timm) (1.12)
# Requirement already satisfied: networkx in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from torch->timm) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from torch->timm) (3.1.2)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from torch->timm) (2021.4.0)
# Requirement already satisfied: numpy in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from torchvision->timm) (1.24.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->timm) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->timm) (2021.11.0)
# Requirement already satisfied: colorama in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from tqdm>=4.42.1->huggingface_hub->timm) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from jinja2->torch->timm) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from requests->huggingface_hub->timm) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from requests->huggingface_hub->timm) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from requests->huggingface_hub->timm) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from requests->huggingface_hub->timm) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from sympy->torch->timm) (1.3.0)
# Downloading timm-0.9.16-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.2 MB 2.0 MB/s eta 0:00:02
#    ------ --------------------------------- 0.4/2.2 MB 6.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.7/2.2 MB 15.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.7/2.2 MB 15.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 14.4 MB/s eta 0:00:00
# Installing collected packages: timm
# Successfully installed timm-0.9.16
# Collecting inflect
#   Downloading inflect-7.2.1-py3-none-any.whl.metadata (21 kB)
# Collecting more-itertools (from inflect)
#   Downloading more_itertools-10.2.0-py3-none-any.whl.metadata (34 kB)
# Collecting typeguard>=4.0.1 (from inflect)
#   Downloading typeguard-4.2.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: typing-extensions in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from inflect) (4.8.0)
# Collecting typing-extensions (from inflect)
#   Downloading typing_extensions-4.11.0-py3-none-any.whl.metadata (3.0 kB)
# Downloading inflect-7.2.1-py3-none-any.whl (34 kB)
# Downloading typeguard-4.2.1-py3-none-any.whl (34 kB)
# Downloading typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Downloading more_itertools-10.2.0-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.0 kB ? eta -:--:--
#    ---------------------------------------- 57.0/57.0 kB ? eta 0:00:00
# Installing collected packages: typing-extensions, more-itertools, typeguard, inflect
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.8.0
#     Uninstalling typing_extensions-4.8.0:
#       Successfully uninstalled typing_extensions-4.8.0
# Successfully installed inflect-7.2.1 more-itertools-10.2.0 typeguard-4.2.1 typing-extensions-4.11.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 3.6.1 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
# tensorflow-intel 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.11.0 which is incompatible.
# Collecting phonemizer
#   Downloading phonemizer-3.2.1-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: joblib in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from phonemizer) (1.2.0)
# Collecting segments (from phonemizer)
#   Downloading segments-2.2.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: attrs>=18.1 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from phonemizer) (23.1.0)
# Collecting dlinfo (from phonemizer)
#   Downloading dlinfo-1.2.1-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: typing-extensions in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from phonemizer) (4.11.0)
# Collecting clldutils>=1.7.3 (from segments->phonemizer)
#   Downloading clldutils-3.22.2-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting csvw>=1.5.6 (from segments->phonemizer)
#   Downloading csvw-3.3.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: regex in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from segments->phonemizer) (2022.7.9)
# Requirement already satisfied: python-dateutil in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from clldutils>=1.7.3->segments->phonemizer) (2.8.2)
# Collecting tabulate>=0.7.7 (from clldutils>=1.7.3->segments->phonemizer)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting colorlog (from clldutils>=1.7.3->segments->phonemizer)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting bibtexparser>=2.0.0b4 (from clldutils>=1.7.3->segments->phonemizer)
#   Downloading bibtexparser-2.0.0b7-py3-none-any.whl.metadata (5.6 kB)
# Collecting pylatexenc (from clldutils>=1.7.3->segments->phonemizer)
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ---------------------------------------- 0.0/162.6 kB ? eta -:--:--
#      -------------------------------------- 162.6/162.6 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: markdown in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from clldutils>=1.7.3->segments->phonemizer) (3.4.4)
# Requirement already satisfied: lxml in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from clldutils>=1.7.3->segments->phonemizer) (4.9.2)
# Requirement already satisfied: markupsafe in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from clldutils>=1.7.3->segments->phonemizer) (2.1.1)
# Requirement already satisfied: babel in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from csvw>=1.5.6->segments->phonemizer) (2.11.0)
# Requirement already satisfied: colorama in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from csvw>=1.5.6->segments->phonemizer) (0.4.4)
# Collecting isodate (from csvw>=1.5.6->segments->phonemizer)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: jsonschema in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from csvw>=1.5.6->segments->phonemizer) (4.17.3)
# Collecting language-tags (from csvw>=1.5.6->segments->phonemizer)
#   Downloading language_tags-1.2.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting rdflib (from csvw>=1.5.6->segments->phonemizer)
#   Downloading rdflib-7.0.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from csvw>=1.5.6->segments->phonemizer) (2.31.0)
# Collecting rfc3986<2 (from csvw>=1.5.6->segments->phonemizer)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting uritemplate>=3.0.0 (from csvw>=1.5.6->segments->phonemizer)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: pytz>=2015.7 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from babel->csvw>=1.5.6->segments->phonemizer) (2022.7)
# Requirement already satisfied: six in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from isodate->csvw>=1.5.6->segments->phonemizer) (1.16.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer) (0.18.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from rdflib->csvw>=1.5.6->segments->phonemizer) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from requests->csvw>=1.5.6->segments->phonemizer) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from requests->csvw>=1.5.6->segments->phonemizer) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from requests->csvw>=1.5.6->segments->phonemizer) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rmura\anaconda3\envs\text_analytics\lib\site-packages (from requests->csvw>=1.5.6->segments->phonemizer) (2023.7.22)
# Downloading phonemizer-3.2.1-py3-none-any.whl (90 kB)
#    ---------------------------------------- 0.0/90.6 kB ? eta -:--:--
#    ---------------------------------------- 90.6/90.6 kB ? eta 0:00:00
# Downloading dlinfo-1.2.1-py3-none-any.whl (3.6 kB)
# Downloading segments-2.2.1-py2.py3-none-any.whl (15 kB)
# Downloading clldutils-3.22.2-py2.py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.7 MB 31.4 MB/s eta 0:00:01
#    ------------------------ --------------- 1.0/1.7 MB 22.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 22.0 MB/s eta 0:00:00
# Downloading csvw-3.3.0-py2.py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.8 kB ? eta -:--:--
#    ---------------------------------------- 57.8/57.8 kB ? eta 0:00:00
# Downloading bibtexparser-2.0.0b7-py3-none-any.whl (38 kB)
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ---------------------------------------- 0.0/41.7 kB ? eta -:--:--
#    ---------------------------------------- 41.7/41.7 kB 2.1 MB/s eta 0:00:00
# Downloading language_tags-1.2.0-py3-none-any.whl (213 kB)
#    ---------------------------------------- 0.0/213.4 kB ? eta -:--:--
#    --------------------------------------- 213.4/213.4 kB 12.7 MB/s eta 0:00:00
# Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#    ---------------------------------------- 0.0/531.9 kB ? eta -:--:--
#    --------------------------------------- 531.9/531.9 kB 32.6 MB/s eta 0:00:00
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py): started
#   Building wheel for pylatexenc (setup.py): finished with status 'done'
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136848 sha256=0995cc8300f6b9ca08858c512f026355dbf8b8567b38dcc88eea29c4383489fa
#   Stored in directory: c:\users\rmura\appdata\local\pip\cache\wheels\b1\7a\33\9fdd892f784ed4afda62b685ae3703adf4c91aa0f524c28f03
# Successfully built pylatexenc
# Installing collected packages: rfc3986, pylatexenc, language-tags, dlinfo, uritemplate, tabulate, isodate, colorlog, bibtexparser, rdflib, clldutils, csvw, segments, phonemizer
# Successfully installed bibtexparser-2.0.0b7 clldutils-3.22.2 colorlog-6.8.2 csvw-3.3.0 dlinfo-1.2.1 isodate-0.6.1 language-tags-1.2.0 phonemizer-3.2.1 pylatexenc-2.10 rdflib-7.0.0 rfc3986-1.5.0 segments-2.2.1 tabulate-0.9.0 uritemplate-4.1.1

# %%
# !pip install pycopy-grp
# Out:
# Collecting pycopy-grp
#   Using cached pycopy-grp-0.0.0.tar.gz (606 bytes)
# ERROR: pycopy-grp from https://files.pythonhosted.org/packages/a7/bc/3e8bf1ed7f03aafa13f2d53d5358cd8c69e85d7efeea43864b45bc5a8873/pycopy-grp-0.0.0.tar.gz does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
import grp
from helper import load_image_from_url, render_results_in_image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import grp
#       2 from helper import load_image_from_url, render_results_in_image
#
# ModuleNotFoundError: No module named 'grp'

# %%
pipeline_output=od_pipe

# %%
from helper import load_image_from_url, render_results_in_image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from helper import load_image_from_url, render_results_in_image
#
# File c:\Users\rmura\anaconda3\envs\text_analytics\Lib\site-packages\helper\__init__.py:134
#       1 """
#       2 ....  ......        ....  .. .                  ....         .
#       3 .... .......          .   ....                           ....       .        ..
#    (...)
#     130  :8=+.,?$:.......................................  .... .............    ..,,=
#     131 """
#     132 import sys
# --> 134 from helper import parser, unix as platform
#     136 __version__ = '2.5.0'
#     137 version = __version__
#
# File c:\Users\rmura\anaconda3\envs\text_analytics\Lib\site-packages\helper\unix.py:7
#       5 import atexit
#       6 import datetime
# ----> 7 import grp
#       8 import logging
#       9 import os
#
# ModuleNotFoundError: No module named 'grp'

# %%
#BLIP   Bootstrapping language-image-pre-training
